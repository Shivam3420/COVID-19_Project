# %%
import pandas as pd
from matplotlib import pyplot as plt
df = pd.read_csv('covid_19_india.csv')
D = df.loc[df['State'] == 'Delhi']
plt.title("COVID-19 INDIA")
plt.plot(D['Confirmed'],D['Cured'])
plt.xlabel("Most Affected",labelpad = 10)
plt.ylabel("Cured",labelpad = 10)
plt.show()
